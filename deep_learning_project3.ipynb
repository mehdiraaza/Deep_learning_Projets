# %%
import numpy as np
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4425852d-23df-400e-bd81-163732eb72b2" name="files[]" multiple disabled />
#      <output id="result-4425852d-23df-400e-bd81-163732eb72b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housing.csv to housing.csv

# %%
# load dataset
dataframe = pandas.read_csv("housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]

# %%
df = pd.read_csv('housing.csv', delim_whitespace = True , header = None)
df
# Out:
#           0     1      2   3      4   ...     9     10      11    12    13
# 0    0.00632  18.0   2.31   0  0.538  ...  296.0  15.3  396.90  4.98  24.0
# 1    0.02731   0.0   7.07   0  0.469  ...  242.0  17.8  396.90  9.14  21.6
# 2    0.02729   0.0   7.07   0  0.469  ...  242.0  17.8  392.83  4.03  34.7
# 3    0.03237   0.0   2.18   0  0.458  ...  222.0  18.7  394.63  2.94  33.4
# 4    0.06905   0.0   2.18   0  0.458  ...  222.0  18.7  396.90  5.33  36.2
# ..       ...   ...    ...  ..    ...  ...    ...   ...     ...   ...   ...
# 501  0.06263   0.0  11.93   0  0.573  ...  273.0  21.0  391.99  9.67  22.4
# 502  0.04527   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  9.08  20.6
# 503  0.06076   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  5.64  23.9
# 504  0.10959   0.0  11.93   0  0.573  ...  273.0  21.0  393.45  6.48  22.0
# 505  0.04741   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# Convert the data into numpy and print 1st row , dimensions , shape and type of data bold text

# %%
dataset = df.values
print(dataset[0])
print(dataset.ndim)
print(dataset.shape)
print(type(dataset))
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00 2.400e+01]
# 2
# (506, 14)
# <class 'numpy.ndarray'>

# %%
x = dataset[:,0:13]
y = dataset[:,13]
print(x[0])
print(y)
print(x.shape)
print(y.shape)
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00]
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
# ...

# %%
from keras import optimizers
def baseline_model():
  baseline_network = Sequential()
  baseline_network.add(Dense(13, activation='relu', input_shape=(13,)))
  baseline_network.add(Dense(1))
  baseline_network.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return baseline_network

# %%
seed = 7
np.random.seed(seed)
estimator = KerasRegressor(build_fn = baseline_model , epochs = 100 , batch_size = 5 , verbose = 0 )
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(estimator , x , y , cv = kfold)
print("Results: %.2f (%.2f) MSE" % (abs(results.mean()), results.std()))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# ...

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = baseline_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 26.941621(32.526215)MSE

# %%
from keras import optimizers
def larger_model():
  larger_network = Sequential()
  larger_network.add(Dense(13, activation='relu', input_shape=(13,)))
  larger_network.add(Dense(7, activation='relu'))
  larger_network.add(Dense(1))
  larger_network.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return larger_network

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = larger_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 21.742179(26.425646)MSE

# %%
from keras import optimizers
def wider_model():
  wider_network = Sequential()
  wider_network.add(Dense(13, activation='relu', input_shape=(13,)))
  wider_network.add(Dense(20, activation='relu'))
  wider_network.add(Dense(1))
  wider_network.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return wider_network

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = wider_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 23.160973(30.863926)MSE

# %%
from keras import optimizers
def overfit_model():
  wider_network = Sequential()
  wider_network.add(Dense(20, activation='relu', input_shape=(13,)))
  wider_network.add(Dense(13, activation='relu'))
  wider_network.add(Dense(6, activation='relu'))
  wider_network.add(Dense(3, activation='relu'))
  wider_network.add(Dense(1))
  wider_network.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return wider_network

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = overfit_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 23.641414(20.065865)MSE

# %%
from keras import optimizers
from keras import regularizers
def tune_model():
  tune_network = Sequential()
  tune_network.add(Dense(13, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(13,)))
  tune_network.add(Dense(6, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
  tune_network.add(Dense(1))
  tune_network.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return tune_network

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = tune_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 22.590963(28.343930)MSE

# %%
from keras.layers import Input, Dense
from keras.models import Model
def functional_model():
  inputs = Input(shape = (13,))
  z1 = Dense(13, kernel_regularizer=regularizers.l2(0.001), activation='relu')(inputs)
  z2 = Dense(6, kernel_regularizer=regularizers.l2(0.001), activation='relu')(z1)
  outputs = Dense(1)(z2)
  model = Model(inputs,outputs)
  model.compile(optimizer= optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='mse' ,metrics=['mae'])
  return model

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = functional_model , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 22.707359(28.251451)MSE

# %%
import tensorflow as tf
class SubclassModel(tf.keras.Model):
    def __init__(self):
        super(SubclassModel,self).__init__()
        self.dense1= tf.keras.layers.Dense(13,activation=tf.nn.relu)
        self.dense2=tf.keras.layers.Dense(6,activation=tf.nn.relu)
        self.dense3= tf.keras.layers.Dense(1)
    def call(self,inputs):
        x=self.dense1(inputs)
        x=self.dense2(x)
        return self.dense3(x)
def finalModel():
    model=SubclassModel()
    model.compile(optimizer='adam', loss='mse' ,metrics=['mae'])
    return model

# %%
np.random.seed(seed)
estimators = []
estimators.append(('standardize' , StandardScaler()))
estimators.append(('mlp' , KerasRegressor(build_fn = finalModel , epochs = 50 , batch_size = 5 , verbose = 0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits = 10 , random_state = seed)
results = cross_val_score(pipeline , x , y , cv = kfold)
print("Results: %2f(%2f)MSE"%(abs(results.mean()),results.std()))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Results: 21.000695(20.997033)MSE

# %%
complete_data = dataset.copy()
data = complete_data[:,0:13]
labels = complete_data[:,13]
train_data = data[:404]
train_labels = labels[:404]
test_data = data[404:]
test_labels = labels[404:]

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %%
from keras import models
from keras import layers
def build_model():
  model = models.Sequential()
  model.add(layers.Dense(64, activation='relu',input_shape=(train_data.shape[1],)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
import numpy as np
k=4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []

# %%
for i in range(k):
  print('processing fold #', i)
  val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_labels[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate(
      [train_data[:i * num_val_samples],train_data[(i + 1) * num_val_samples:]],axis=0)
  partial_train_targets = np.concatenate( [train_labels[:i * num_val_samples], train_labels[(i + 1) * num_val_samples:]],axis=0)
  model = build_model()
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
all_scores
# Out:
# [3.0913015356158264, 4.165283677601578, 3.2216729079142654, 10.706292067423906]

# %%
np.mean(all_scores)
# Out:
# 5.296137547138894

# %%
model = build_model()
model.fit(train_data, train_labels,
epochs=80, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_labels)
print(test_mse_score)
# Out:
# 102/102 [==============================] - 2s 17ms/step
# 45.10672258863262
